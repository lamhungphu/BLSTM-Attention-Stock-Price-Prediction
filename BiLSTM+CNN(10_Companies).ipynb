# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
# %matplotlib inline
from matplotlib.pylab import rcParams
from datetime import datetime
import warnings
from pylab import rcParams
from sklearn.model_selection import train_test_split as split
import warnings
import itertools
warnings.filterwarnings("ignore")
from IPython import display
from matplotlib import pyplot
import os
import re
import plotly.express as px
import warnings
from matplotlib.patches import Patch

# %%
import os
fileList = os.listdir("/content/")
fileList
# Out:
# ['.config',
#  'TCEHY.csv',
#  'NFLX.csv',
#  'MSFT.csv',
#  'NVDA.csv',
#  'TSLA.csv',
#  'AMZN.csv',
#  'BIDU.csv',
#  'GOOG.csv',
#  'AAPL.csv',
#  'INTC.csv',
#  'sample_data']

# %%
#companyName != "" and companyName !="sample_data"
companyList = []
for file in fileList:
    companyName = file.split(".")[0]
    if  companyName != "" and companyName !="sample_data":
        companyList.append(companyName)
print(companyList)
# Out:
# ['TCEHY', 'NFLX', 'MSFT', 'NVDA', 'TSLA', 'AMZN', 'BIDU', 'GOOG', 'AAPL', 'INTC']

# %%
import pandas as pd
# First, we get the data
stockList = ['AMZN', 'NVDA','AAPL','BIDU','GOOG','INTC','MSFT','NFLX','TCEHY','TSLA']
df_ = {}
for i in stockList:
    df_[i] = pd.read_csv("/content/" + i + ".csv", index_col = 'Date')

# %%
from sklearn.model_selection import train_test_split
def split(dataframe, border, col):
    return dataframe.loc[:border,col], dataframe.loc[border:,col]

df_new = {}
for i in stockList:
    df_new[i] = {}
    # train / test split
    df_new[i]["Train"] = df_[i].query('Date <=  "2019-03-13"').reset_index(drop = False)
    df_new[i]["Test"]  = df_[i].query('Date >= "2019-03-13"').reset_index(drop = False)

# %%
for i in stockList:
  df_new[i]["Train"].drop(columns=['Open', 'High','Low','Adj Close','Volume'],inplace = True)
  df_new[i]["Test"].drop(columns=['Open', 'High','Low','Adj Close','Volume'],inplace = True)

# %%
df_new[i]["Train"]
# Out:
#             Date      Close
# 0     2012-01-03   1.872000
# 1     2012-01-04   1.847333
# 2     2012-01-05   1.808000
# 3     2012-01-06   1.794000
# 4     2012-01-09   1.816667
# ...          ...        ...
# 1804  2019-03-07  18.439333
# 1805  2019-03-08  18.942667
# 1806  2019-03-11  19.394667
# 1807  2019-03-12  18.890667
# 1808  2019-03-13  19.264000
#
# [1809 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
# Scaling the training set
transform_train = {}
transform_test = {}
scaler = {}

for num, i in enumerate(stockList):
    sc = MinMaxScaler(feature_range=(0,1))
    a0 = np.array(df_new[i]["Train"]['Close'])
    a1 = np.array(df_new[i]["Test"]['Close'])
    a0 = a0.reshape(a0.shape[0],1)
    a1 = a1.reshape(a1.shape[0],1)
    transform_train[i] = sc.fit_transform(a0)
    transform_test[i] = sc.fit_transform(a1)
    scaler[i] = sc

del a0
del a1

# %%
for i in transform_train.keys():
    print(i, transform_train[i].shape)
print("\n")
for i in transform_test.keys():
    print(i, transform_test[i].shape)
# Out:
# AMZN (1809, 1)
# NVDA (1809, 1)
# AAPL (1809, 1)
# BIDU (1809, 1)
# GOOG (1809, 1)
# INTC (1809, 1)
# MSFT (1809, 1)
# NFLX (1809, 1)
# TCEHY (1809, 1)
# TSLA (1809, 1)
#
#
# AMZN (453, 1)
# NVDA (453, 1)
# AAPL (453, 1)
# BIDU (453, 1)
# GOOG (453, 1)
# INTC (453, 1)
# MSFT (453, 1)
# NFLX (453, 1)
# TCEHY (453, 1)
# TSLA (453, 1)

# %%
trainset = {}
testset = {}
for j in stockList:
    trainset[j] = {}
    X_train = []
    y_train = []
    for i in range(10,1809):
        X_train.append(transform_train[j][i-10:i,0])
        y_train.append(transform_train[j][i,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
    trainset[j]["X"] = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    trainset[j]["y"] = y_train

    testset[j] = {}
    X_test = []
    y_test = []
    for i in range(10, 453):
        X_test.append(transform_test[j][i-10:i,0])
        y_test.append(transform_test[j][i,0])
    X_test, y_test = np.array(X_test), np.array(y_test)
    testset[j]["X"] = np.reshape(X_test, (X_test.shape[0], X_train.shape[1], 1))
    testset[j]["y"] = y_test

# %%
arr_buff = []
for i in stockList:
    buff = {}
    buff["X_train"] = trainset[i]["X"].shape
    buff["y_train"] = trainset[i]["y"].shape
    buff["X_test"] = testset[i]["X"].shape
    buff["y_test"] = testset[i]["y"].shape
    arr_buff.append(buff)

pd.DataFrame(arr_buff, index=stockList)
# Out:
#              X_train  y_train        X_test  y_test
# AMZN   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# NVDA   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# AAPL   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# BIDU   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# GOOG   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# INTC   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# MSFT   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# NFLX   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# TCEHY  (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)
# TSLA   (1799, 10, 1)  (1799,)  (443, 10, 1)  (443,)

# %%
import tensorflow as tf
tf.random.set_seed(1234)
from keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.models import Model
# class attention(Layer):
#     def __init__(self,**kwargs):
#         super(attention,self).__init__(**kwargs)

#     def build(self,input_shape):
#         self.W=self.add_weight(name='attention_weight', shape=(input_shape[-1],1),
#                                initializer='random_normal', trainable=True)
#         self.b=self.add_weight(name='attention_bias', shape=(input_shape[1],1),
#                                initializer='zeros', trainable=True)
#         super(attention, self).build(input_shape)

#     def call(self,x):
#         # Alignment scores. Pass them through tanh function
#         e = K.tanh(K.dot(x,self.W)+self.b)
#         # Remove dimension of size 1
#         e = K.squeeze(e, axis=-1)
#         # Compute the weights
#         alpha = K.softmax(e)
#         # Reshape to tensorFlow format
#         alpha = K.expand_dims(alpha, axis=-1)
#         # Compute the context vector
#         context = x * alpha
#         context = K.sum(context, axis=1)
#         return context

# %%
time_steps = 10
n_features = 1
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Input, Dense, LSTM, Conv1D, Dropout, Bidirectional, Multiply
from tensorflow.keras.layers import InputLayer
def LSTMandCNN(input_shape):
    inputs = Input(shape=input_shape)
    x = Conv1D(filters=256, kernel_size=1, activation='relu')(inputs)
    bi1 = Bidirectional(LSTM(128, activation='relu', return_sequences=True))(x)
    max1d= tf.keras.layers.GlobalAveragePooling1D()(bi1)
    dropout = Dropout(0.2)(max1d)
    dense1=Dense(128)(dropout)
    dense2=Dense(64)(dense1)
    dense3=Dense(1)(dense2)
    model=Model([inputs],dense3)
    model.compile(loss='mse', optimizer='adam')
    return model

model = LSTMandCNN(input_shape=(time_steps,1))
model.summary()
model.compile(optimizer = 'adam',loss = 'mse')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5068db880d72> in <cell line: 21>()
#      19     return model
#      20
# ---> 21 model = LSTMandCNN(input_shape=(time_steps,1))
#      22 model.summary()
#      23 model.compile(optimizer = 'adam',loss = 'mse')
#
# <ipython-input-1-5068db880d72> in LSTMandCNN(input_shape)
#      15     dense2=Dense(64)(dense1)
#      16     dense3=Dense(1)(dense2)
# ---> 17     model=Model([inputs],dense3)
#      18     model.compile(loss='mse', optimizer='adam')
#      19     return model
#
# NameError: name 'Model' is not defined

# %%
for i in stockList:
    print("Fitting to", i)
    history = model.fit(trainset[i]["X"], trainset[i]["y"], epochs=150, batch_size=32, validation_split=0.2)
# Out:
# Fitting to AMZN
# Epoch 1/150
# 45/45 [==============================] - 7s 58ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 2/150
# 45/45 [==============================] - 2s 49ms/step - loss: 3.0836e-04 - val_loss: 0.0018
# Epoch 3/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.4510e-04 - val_loss: 0.0014
# Epoch 4/150
# 45/45 [==============================] - 3s 64ms/step - loss: 2.3404e-04 - val_loss: 0.0013
# Epoch 5/150
# 45/45 [==============================] - 3s 57ms/step - loss: 2.6151e-04 - val_loss: 0.0012
# Epoch 6/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.8211e-04 - val_loss: 0.0011
# Epoch 7/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.3593e-04 - val_loss: 0.0015
# Epoch 8/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7987e-04 - val_loss: 0.0011
# Epoch 9/150
# 45/45 [==============================] - 2s 54ms/step - loss: 1.8876e-04 - val_loss: 0.0011
# Epoch 10/150
# 45/45 [==============================] - 3s 69ms/step - loss: 1.6200e-04 - val_loss: 0.0011
# Epoch 11/150
# 45/45 [==============================] - 2s 52ms/step - loss: 1.9918e-04 - val_loss: 0.0022
# Epoch 12/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9347e-04 - val_loss: 0.0015
# Epoch 13/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7292e-04 - val_loss: 0.0011
# Epoch 14/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7244e-04 - val_loss: 0.0013
# Epoch 15/150
# 45/45 [==============================] - 3s 75ms/step - loss: 2.3352e-04 - val_loss: 0.0011
# Epoch 16/150
# 45/45 [==============================] - 2s 47ms/step - loss: 2.1872e-04 - val_loss: 0.0017
# Epoch 17/150
# 45/45 [==============================] - 2s 55ms/step - loss: 1.6499e-04 - val_loss: 0.0014
# Epoch 18/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.8775e-04 - val_loss: 0.0015
# Epoch 19/150
# 45/45 [==============================] - 3s 61ms/step - loss: 1.7637e-04 - val_loss: 0.0010
# Epoch 20/150
# 45/45 [==============================] - 5s 102ms/step - loss: 1.7647e-04 - val_loss: 0.0011
# Epoch 21/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7687e-04 - val_loss: 0.0013
# Epoch 22/150
# 45/45 [==============================] - 2s 47ms/step - loss: 2.0018e-04 - val_loss: 0.0022
# Epoch 23/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9445e-04 - val_loss: 0.0019
# Epoch 24/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0556e-04 - val_loss: 0.0011
# Epoch 25/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.6613e-04 - val_loss: 0.0010
# Epoch 26/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.9205e-04 - val_loss: 0.0011
# Epoch 27/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.6268e-04 - val_loss: 0.0011
# Epoch 28/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.3889e-04 - val_loss: 0.0013
# Epoch 29/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9619e-04 - val_loss: 0.0029
# Epoch 30/150
# 45/45 [==============================] - 3s 66ms/step - loss: 1.8471e-04 - val_loss: 0.0010
# Epoch 31/150
# 45/45 [==============================] - 3s 56ms/step - loss: 1.6663e-04 - val_loss: 0.0017
# Epoch 32/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.6206e-04 - val_loss: 0.0011
# Epoch 33/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.6174e-04 - val_loss: 0.0010
# Epoch 34/150
# 45/45 [==============================] - 3s 63ms/step - loss: 1.6018e-04 - val_loss: 0.0025
# Epoch 35/150
# 45/45 [==============================] - 4s 82ms/step - loss: 1.8952e-04 - val_loss: 0.0027
# Epoch 36/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.5902e-04 - val_loss: 9.8811e-04
# Epoch 37/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.7165e-04 - val_loss: 0.0012
# Epoch 38/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.8506e-04 - val_loss: 0.0011
# Epoch 39/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.5481e-04 - val_loss: 0.0021
# Epoch 40/150
# 45/45 [==============================] - 3s 63ms/step - loss: 2.6293e-04 - val_loss: 0.0011
# Epoch 41/150
# 45/45 [==============================] - 3s 58ms/step - loss: 2.0664e-04 - val_loss: 0.0012
# Epoch 42/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7422e-04 - val_loss: 0.0020
# Epoch 43/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9225e-04 - val_loss: 0.0021
# Epoch 44/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.6020e-04 - val_loss: 0.0013
# Epoch 45/150
# 45/45 [==============================] - 3s 56ms/step - loss: 1.9275e-04 - val_loss: 0.0016
# Epoch 46/150
# 45/45 [==============================] - 3s 68ms/step - loss: 1.9983e-04 - val_loss: 0.0020
# Epoch 47/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.1257e-04 - val_loss: 0.0031
# Epoch 48/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.5290e-04 - val_loss: 0.0020
# Epoch 49/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7467e-04 - val_loss: 0.0032
# Epoch 50/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7895e-04 - val_loss: 0.0021
# Epoch 51/150
# 45/45 [==============================] - 3s 74ms/step - loss: 1.7389e-04 - val_loss: 0.0017
# Epoch 52/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.5373e-04 - val_loss: 0.0042
# Epoch 53/150
# 45/45 [==============================] - 2s 47ms/step - loss: 1.7104e-04 - val_loss: 0.0040
# Epoch 54/150
# 45/45 [==============================] - 2s 47ms/step - loss: 1.9237e-04 - val_loss: 0.0011
# Epoch 55/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6764e-04 - val_loss: 0.0051
# Epoch 56/150
# 45/45 [==============================] - 3s 63ms/step - loss: 2.1673e-04 - val_loss: 0.0039
# Epoch 57/150
# 45/45 [==============================] - 3s 57ms/step - loss: 1.8467e-04 - val_loss: 0.0045
# Epoch 58/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.3703e-04 - val_loss: 9.6220e-04
# Epoch 59/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7915e-04 - val_loss: 0.0021
# Epoch 60/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6386e-04 - val_loss: 0.0019
# Epoch 61/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.6528e-04 - val_loss: 9.7776e-04
# Epoch 62/150
# 45/45 [==============================] - 3s 73ms/step - loss: 1.7119e-04 - val_loss: 0.0023
# Epoch 63/150
# 45/45 [==============================] - 2s 47ms/step - loss: 1.6741e-04 - val_loss: 9.6833e-04
# Epoch 64/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.1283e-04 - val_loss: 0.0014
# Epoch 65/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.1720e-04 - val_loss: 0.0035
# Epoch 66/150
# 45/45 [==============================] - 2s 47ms/step - loss: 1.8007e-04 - val_loss: 0.0057
# Epoch 67/150
# 45/45 [==============================] - 3s 70ms/step - loss: 1.6649e-04 - val_loss: 0.0013
# Epoch 68/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.1359e-04 - val_loss: 0.0015
# Epoch 69/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6859e-04 - val_loss: 0.0029
# Epoch 70/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.5709e-04 - val_loss: 0.0015
# Epoch 71/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.5020e-04 - val_loss: 0.0021
# Epoch 72/150
# 45/45 [==============================] - 3s 60ms/step - loss: 1.8552e-04 - val_loss: 0.0044
# Epoch 73/150
# 45/45 [==============================] - 3s 61ms/step - loss: 1.9009e-04 - val_loss: 0.0049
# Epoch 74/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9162e-04 - val_loss: 0.0077
# Epoch 75/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6366e-04 - val_loss: 0.0066
# Epoch 76/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.8483e-04 - val_loss: 0.0011
# Epoch 77/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6277e-04 - val_loss: 0.0053
# Epoch 78/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.7652e-04 - val_loss: 0.0019
# Epoch 79/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.0897e-04 - val_loss: 0.0027
# Epoch 80/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.8964e-04 - val_loss: 0.0062
# Epoch 81/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.0038e-04 - val_loss: 0.0058
# Epoch 82/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7882e-04 - val_loss: 0.0040
# Epoch 83/150
# 45/45 [==============================] - 3s 67ms/step - loss: 1.6852e-04 - val_loss: 0.0083
# Epoch 84/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.2538e-04 - val_loss: 0.0040
# Epoch 85/150
# 45/45 [==============================] - 2s 47ms/step - loss: 1.9449e-04 - val_loss: 0.0042
# Epoch 86/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7265e-04 - val_loss: 0.0062
# Epoch 87/150
# 45/45 [==============================] - 2s 47ms/step - loss: 2.0814e-04 - val_loss: 0.0053
# Epoch 88/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.6223e-04 - val_loss: 0.0033
# Epoch 89/150
# 45/45 [==============================] - 3s 70ms/step - loss: 1.8151e-04 - val_loss: 0.0033
# Epoch 90/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9629e-04 - val_loss: 0.0027
# Epoch 91/150
# 45/45 [==============================] - 2s 47ms/step - loss: 1.8344e-04 - val_loss: 0.0014
# Epoch 92/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.1744e-04 - val_loss: 0.0066
# Epoch 93/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6790e-04 - val_loss: 0.0030
# Epoch 94/150
# 45/45 [==============================] - 3s 69ms/step - loss: 1.8525e-04 - val_loss: 0.0042
# Epoch 95/150
# 45/45 [==============================] - 3s 56ms/step - loss: 1.7798e-04 - val_loss: 0.0047
# Epoch 96/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9571e-04 - val_loss: 0.0034
# Epoch 97/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7985e-04 - val_loss: 0.0041
# Epoch 98/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6703e-04 - val_loss: 0.0044
# Epoch 99/150
# 45/45 [==============================] - 3s 65ms/step - loss: 1.6612e-04 - val_loss: 0.0035
# Epoch 100/150
# 45/45 [==============================] - 4s 89ms/step - loss: 1.5952e-04 - val_loss: 0.0076
# Epoch 101/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7277e-04 - val_loss: 0.0035
# Epoch 102/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7513e-04 - val_loss: 0.0090
# Epoch 103/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.2472e-04 - val_loss: 0.0028
# Epoch 104/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6672e-04 - val_loss: 0.0051
# Epoch 105/150
# 45/45 [==============================] - 3s 67ms/step - loss: 1.3480e-04 - val_loss: 0.0039
# Epoch 106/150
# 45/45 [==============================] - 2s 55ms/step - loss: 1.4653e-04 - val_loss: 0.0046
# Epoch 107/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6007e-04 - val_loss: 0.0059
# Epoch 108/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.8350e-04 - val_loss: 0.0124
# Epoch 109/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6448e-04 - val_loss: 0.0048
# Epoch 110/150
# 45/45 [==============================] - 2s 53ms/step - loss: 1.6410e-04 - val_loss: 0.0048
# Epoch 111/150
# 45/45 [==============================] - 3s 68ms/step - loss: 1.7300e-04 - val_loss: 0.0081
# Epoch 112/150
# 45/45 [==============================] - 2s 46ms/step - loss: 1.7466e-04 - val_loss: 0.0097
# Epoch 113/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.5992e-04 - val_loss: 0.0107
# Epoch 114/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.7091e-04 - val_loss: 0.0046
# Epoch 115/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.4782e-04 - val_loss: 0.0076
# Epoch 116/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.7019e-04 - val_loss: 0.0065
# Epoch 117/150
# 45/45 [==============================] - 2s 47ms/step - loss: 1.6079e-04 - val_loss: 0.0066
# Epoch 118/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.6385e-04 - val_loss: 0.0066
# Epoch 119/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9285e-04 - val_loss: 0.0076
# Epoch 120/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.1327e-04 - val_loss: 0.0138
# Epoch 121/150
# 45/45 [==============================] - 3s 66ms/step - loss: 1.9558e-04 - val_loss: 0.0023
# Epoch 122/150
# 45/45 [==============================] - 3s 56ms/step - loss: 1.8817e-04 - val_loss: 0.0066
# Epoch 123/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7159e-04 - val_loss: 0.0092
# Epoch 124/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.3944e-04 - val_loss: 0.0101
# Epoch 125/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.5423e-04 - val_loss: 0.0088
# Epoch 126/150
# 45/45 [==============================] - 2s 55ms/step - loss: 1.5670e-04 - val_loss: 0.0047
# Epoch 127/150
# 45/45 [==============================] - 3s 67ms/step - loss: 1.5822e-04 - val_loss: 0.0069
# Epoch 128/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.5472e-04 - val_loss: 0.0110
# Epoch 129/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.8248e-04 - val_loss: 0.0092
# Epoch 130/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.7819e-04 - val_loss: 0.0053
# Epoch 131/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7515e-04 - val_loss: 0.0066
# Epoch 132/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.9005e-04 - val_loss: 0.0037
# Epoch 133/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6731e-04 - val_loss: 0.0050
# Epoch 134/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7548e-04 - val_loss: 0.0087
# Epoch 135/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.5065e-04 - val_loss: 0.0047
# Epoch 136/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.1782e-04 - val_loss: 0.0103
# Epoch 137/150
# 45/45 [==============================] - 3s 66ms/step - loss: 1.4693e-04 - val_loss: 0.0082
# Epoch 138/150
# 45/45 [==============================] - 3s 56ms/step - loss: 1.5554e-04 - val_loss: 0.0062
# Epoch 139/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.5471e-04 - val_loss: 0.0091
# Epoch 140/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.5861e-04 - val_loss: 0.0082
# Epoch 141/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6149e-04 - val_loss: 0.0042
# Epoch 142/150
# 45/45 [==============================] - 2s 56ms/step - loss: 1.8594e-04 - val_loss: 0.0061
# Epoch 143/150
# 45/45 [==============================] - 3s 67ms/step - loss: 1.5031e-04 - val_loss: 0.0107
# Epoch 144/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.0684e-04 - val_loss: 0.0056
# Epoch 145/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.4552e-04 - val_loss: 0.0103
# Epoch 146/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.7262e-04 - val_loss: 0.0126
# Epoch 147/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.4282e-04 - val_loss: 0.0147
# Epoch 148/150
# 45/45 [==============================] - 3s 75ms/step - loss: 1.5763e-04 - val_loss: 0.0069
# Epoch 149/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.5347e-04 - val_loss: 0.0085
# Epoch 150/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.4588e-04 - val_loss: 0.0083
# Fitting to NVDA
# Epoch 1/150
# 45/45 [==============================] - 3s 70ms/step - loss: 2.0294e-04 - val_loss: 0.0059
# Epoch 2/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.2503e-04 - val_loss: 0.0024
# Epoch 3/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.6372e-04 - val_loss: 0.0026
# Epoch 4/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0182e-04 - val_loss: 0.0030
# Epoch 5/150
# 45/45 [==============================] - 2s 47ms/step - loss: 2.3053e-04 - val_loss: 0.0023
# Epoch 6/150
# 45/45 [==============================] - 4s 85ms/step - loss: 2.3400e-04 - val_loss: 0.0033
# Epoch 7/150
# 45/45 [==============================] - 3s 68ms/step - loss: 2.6795e-04 - val_loss: 0.0122
# Epoch 8/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.8841e-04 - val_loss: 0.0039
# Epoch 9/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.1054e-04 - val_loss: 0.0087
# Epoch 10/150
# 45/45 [==============================] - 2s 49ms/step - loss: 3.2317e-04 - val_loss: 0.0041
# Epoch 11/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.4725e-04 - val_loss: 0.0040
# Epoch 12/150
# 45/45 [==============================] - 3s 71ms/step - loss: 3.0924e-04 - val_loss: 0.0146
# Epoch 13/150
# 45/45 [==============================] - 2s 47ms/step - loss: 2.5253e-04 - val_loss: 0.0054
# Epoch 14/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.0794e-04 - val_loss: 0.0036
# Epoch 15/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.3765e-04 - val_loss: 0.0039
# Epoch 16/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.2958e-04 - val_loss: 0.0031
# Epoch 17/150
# 45/45 [==============================] - 3s 77ms/step - loss: 2.2911e-04 - val_loss: 0.0089
# Epoch 18/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.6246e-04 - val_loss: 0.0031
# Epoch 19/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.5285e-04 - val_loss: 0.0073
# Epoch 20/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.3244e-04 - val_loss: 0.0077
# Epoch 21/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0924e-04 - val_loss: 0.0124
# Epoch 22/150
# 45/45 [==============================] - 3s 65ms/step - loss: 1.8972e-04 - val_loss: 0.0046
# Epoch 23/150
# 45/45 [==============================] - 3s 59ms/step - loss: 2.1211e-04 - val_loss: 0.0058
# Epoch 24/150
# 45/45 [==============================] - 2s 49ms/step - loss: 3.2409e-04 - val_loss: 0.0089
# Epoch 25/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.1994e-04 - val_loss: 0.0143
# Epoch 26/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.0456e-04 - val_loss: 0.0069
# Epoch 27/150
# 45/45 [==============================] - 2s 54ms/step - loss: 2.0471e-04 - val_loss: 0.0195
# Epoch 28/150
# 45/45 [==============================] - 3s 68ms/step - loss: 2.2786e-04 - val_loss: 0.0108
# Epoch 29/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.0461e-04 - val_loss: 0.0134
# Epoch 30/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0998e-04 - val_loss: 0.0135
# Epoch 31/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0249e-04 - val_loss: 0.0088
# Epoch 32/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.2151e-04 - val_loss: 0.0109
# Epoch 33/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.7631e-04 - val_loss: 0.0061
# Epoch 34/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.9106e-04 - val_loss: 0.0093
# Epoch 35/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.2681e-04 - val_loss: 0.0088
# Epoch 36/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.1784e-04 - val_loss: 0.0199
# Epoch 37/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.0289e-04 - val_loss: 0.0116
# Epoch 38/150
# 45/45 [==============================] - 3s 70ms/step - loss: 1.9696e-04 - val_loss: 0.0101
# Epoch 39/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.5079e-04 - val_loss: 0.0081
# Epoch 40/150
# 45/45 [==============================] - 2s 47ms/step - loss: 2.3094e-04 - val_loss: 0.0081
# Epoch 41/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.3585e-04 - val_loss: 0.0147
# Epoch 42/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.6077e-04 - val_loss: 0.0091
# Epoch 43/150
# 45/45 [==============================] - 3s 62ms/step - loss: 2.3420e-04 - val_loss: 0.0076
# Epoch 44/150
# 45/45 [==============================] - 3s 62ms/step - loss: 2.2457e-04 - val_loss: 0.0149
# Epoch 45/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.7712e-04 - val_loss: 0.0093
# Epoch 46/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.5019e-04 - val_loss: 0.0189
# Epoch 47/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.4195e-04 - val_loss: 0.0046
# Epoch 48/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.3153e-04 - val_loss: 0.0060
# Epoch 49/150
# 45/45 [==============================] - 3s 75ms/step - loss: 2.3320e-04 - val_loss: 0.0092
# Epoch 50/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9898e-04 - val_loss: 0.0126
# Epoch 51/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.0079e-04 - val_loss: 0.0113
# Epoch 52/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.5027e-04 - val_loss: 0.0154
# Epoch 53/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9953e-04 - val_loss: 0.0114
# Epoch 54/150
# 45/45 [==============================] - 3s 77ms/step - loss: 2.1265e-04 - val_loss: 0.0097
# Epoch 55/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.1345e-04 - val_loss: 0.0156
# Epoch 56/150
# 45/45 [==============================] - 2s 48ms/step - loss: 2.0544e-04 - val_loss: 0.0075
# Epoch 57/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9888e-04 - val_loss: 0.0103
# Epoch 58/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.3949e-04 - val_loss: 0.0049
# Epoch 59/150
# 45/45 [==============================] - 3s 64ms/step - loss: 2.1183e-04 - val_loss: 0.0143
# Epoch 60/150
# 45/45 [==============================] - 3s 59ms/step - loss: 1.7167e-04 - val_loss: 0.0096
# Epoch 61/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7925e-04 - val_loss: 0.0090
# Epoch 62/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.6800e-04 - val_loss: 0.0126
# Epoch 63/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.3699e-04 - val_loss: 0.0150
# Epoch 64/150
# 45/45 [==============================] - 3s 56ms/step - loss: 2.1368e-04 - val_loss: 0.0101
# Epoch 65/150
# 45/45 [==============================] - 3s 66ms/step - loss: 2.7988e-04 - val_loss: 0.0168
# Epoch 66/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.3128e-04 - val_loss: 0.0141
# Epoch 67/150
# 45/45 [==============================] - 2s 52ms/step - loss: 1.7941e-04 - val_loss: 0.0134
# Epoch 68/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0551e-04 - val_loss: 0.0139
# Epoch 69/150
# 45/45 [==============================] - 2s 54ms/step - loss: 1.9486e-04 - val_loss: 0.0081
# Epoch 70/150
# 45/45 [==============================] - 4s 88ms/step - loss: 2.0444e-04 - val_loss: 0.0175
# Epoch 71/150
# 45/45 [==============================] - 3s 60ms/step - loss: 1.9586e-04 - val_loss: 0.0115
# Epoch 72/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.2243e-04 - val_loss: 0.0196
# Epoch 73/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.5010e-04 - val_loss: 0.0149
# Epoch 74/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.2322e-04 - val_loss: 0.0153
# Epoch 75/150
# 45/45 [==============================] - 3s 63ms/step - loss: 1.7599e-04 - val_loss: 0.0096
# Epoch 76/150
# 45/45 [==============================] - 3s 63ms/step - loss: 2.1504e-04 - val_loss: 0.0192
# Epoch 77/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.8173e-04 - val_loss: 0.0137
# Epoch 78/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6529e-04 - val_loss: 0.0141
# Epoch 79/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.8762e-04 - val_loss: 0.0095
# Epoch 80/150
# 45/45 [==============================] - 2s 53ms/step - loss: 1.6170e-04 - val_loss: 0.0133
# Epoch 81/150
# 45/45 [==============================] - 3s 76ms/step - loss: 1.8703e-04 - val_loss: 0.0123
# Epoch 82/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.8551e-04 - val_loss: 0.0156
# Epoch 83/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.8600e-04 - val_loss: 0.0125
# Epoch 84/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.7700e-04 - val_loss: 0.0266
# Epoch 85/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.9169e-04 - val_loss: 0.0115
# Epoch 86/150
# 45/45 [==============================] - 3s 74ms/step - loss: 1.8870e-04 - val_loss: 0.0072
# Epoch 87/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.7852e-04 - val_loss: 0.0134
# Epoch 88/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.8127e-04 - val_loss: 0.0138
# Epoch 89/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9926e-04 - val_loss: 0.0090
# Epoch 90/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9679e-04 - val_loss: 0.0114
# Epoch 91/150
# 45/45 [==============================] - 3s 73ms/step - loss: 2.3302e-04 - val_loss: 0.0097
# Epoch 92/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.3360e-04 - val_loss: 0.0159
# Epoch 93/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9725e-04 - val_loss: 0.0091
# Epoch 94/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.1453e-04 - val_loss: 0.0059
# Epoch 95/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.1973e-04 - val_loss: 0.0123
# Epoch 96/150
# 45/45 [==============================] - 3s 65ms/step - loss: 1.7552e-04 - val_loss: 0.0069
# Epoch 97/150
# 45/45 [==============================] - 3s 61ms/step - loss: 1.7464e-04 - val_loss: 0.0078
# Epoch 98/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.1202e-04 - val_loss: 0.0141
# Epoch 99/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.1285e-04 - val_loss: 0.0127
# Epoch 100/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.4770e-04 - val_loss: 0.0095
# Epoch 101/150
# 45/45 [==============================] - 3s 57ms/step - loss: 1.8704e-04 - val_loss: 0.0111
# Epoch 102/150
# 45/45 [==============================] - 3s 66ms/step - loss: 1.9777e-04 - val_loss: 0.0137
# Epoch 103/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.7813e-04 - val_loss: 0.0101
# Epoch 104/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.8008e-04 - val_loss: 0.0136
# Epoch 105/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.6399e-04 - val_loss: 0.0138
# Epoch 106/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.9389e-04 - val_loss: 0.0122
# Epoch 107/150
# 45/45 [==============================] - 3s 77ms/step - loss: 2.0604e-04 - val_loss: 0.0065
# Epoch 108/150
# 45/45 [==============================] - 2s 54ms/step - loss: 1.8672e-04 - val_loss: 0.0156
# Epoch 109/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.5581e-04 - val_loss: 0.0096
# Epoch 110/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.5347e-04 - val_loss: 0.0114
# Epoch 111/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.6234e-04 - val_loss: 0.0118
# Epoch 112/150
# 45/45 [==============================] - 3s 77ms/step - loss: 1.7702e-04 - val_loss: 0.0092
# Epoch 113/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0183e-04 - val_loss: 0.0186
# Epoch 114/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.2875e-04 - val_loss: 0.0144
# Epoch 115/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.0494e-04 - val_loss: 0.0172
# Epoch 116/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.2547e-04 - val_loss: 0.0094
# Epoch 117/150
# 45/45 [==============================] - 3s 72ms/step - loss: 1.9453e-04 - val_loss: 0.0161
# Epoch 118/150
# 45/45 [==============================] - 2s 52ms/step - loss: 1.8644e-04 - val_loss: 0.0155
# Epoch 119/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.2477e-04 - val_loss: 0.0141
# Epoch 120/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.7453e-04 - val_loss: 0.0103
# Epoch 121/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.8811e-04 - val_loss: 0.0136
# Epoch 122/150
# 45/45 [==============================] - 3s 60ms/step - loss: 2.0532e-04 - val_loss: 0.0072
# Epoch 123/150
# 45/45 [==============================] - 3s 63ms/step - loss: 2.0979e-04 - val_loss: 0.0030
# Epoch 124/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9161e-04 - val_loss: 0.0103
# Epoch 125/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.6126e-04 - val_loss: 0.0085
# Epoch 126/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.8392e-04 - val_loss: 0.0105
# Epoch 127/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9067e-04 - val_loss: 0.0120
# Epoch 128/150
# 45/45 [==============================] - 3s 74ms/step - loss: 1.9417e-04 - val_loss: 0.0102
# Epoch 129/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.0738e-04 - val_loss: 0.0098
# Epoch 130/150
# 45/45 [==============================] - 2s 48ms/step - loss: 1.9417e-04 - val_loss: 0.0090
# Epoch 131/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.4377e-04 - val_loss: 0.0085
# Epoch 132/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.0434e-04 - val_loss: 0.0094
# Epoch 133/150
# 45/45 [==============================] - 3s 72ms/step - loss: 2.2570e-04 - val_loss: 0.0061
# Epoch 134/150
# 45/45 [==============================] - 3s 62ms/step - loss: 1.9051e-04 - val_loss: 0.0086
# Epoch 135/150
# 45/45 [==============================] - 3s 67ms/step - loss: 1.8334e-04 - val_loss: 0.0118
# Epoch 136/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.9246e-04 - val_loss: 0.0136
# Epoch 137/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.6532e-04 - val_loss: 0.0088
# Epoch 138/150
# 45/45 [==============================] - 3s 73ms/step - loss: 1.9120e-04 - val_loss: 0.0119
# Epoch 139/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.2567e-04 - val_loss: 0.0102
# Epoch 140/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.8491e-04 - val_loss: 0.0106
# Epoch 141/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.0861e-04 - val_loss: 0.0109
# Epoch 142/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.9330e-04 - val_loss: 0.0055
# Epoch 143/150
# 45/45 [==============================] - 3s 75ms/step - loss: 2.1496e-04 - val_loss: 0.0140
# Epoch 144/150
# 45/45 [==============================] - 2s 51ms/step - loss: 1.6736e-04 - val_loss: 0.0141
# Epoch 145/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.7909e-04 - val_loss: 0.0090
# Epoch 146/150
# 45/45 [==============================] - 2s 49ms/step - loss: 1.9016e-04 - val_loss: 0.0103
# Epoch 147/150
# 45/45 [==============================] - 2s 50ms/step - loss: 1.5644e-04 - val_loss: 0.0173
# Epoch 148/150
# 45/45 [==============================] - 3s 65ms/step - loss: 1.8865e-04 - val_loss: 0.0135
# Epoch 149/150
# 45/45 [==============================] - 3s 59ms/step - loss: 2.0831e-04 - val_loss: 0.0155
# Epoch 150/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.2379e-04 - val_loss: 0.0105
# Fitting to AAPL
# Epoch 1/150
# 45/45 [==============================] - 2s 51ms/step - loss: 4.3784e-04 - val_loss: 0.0115
# Epoch 2/150
# 45/45 [==============================] - 2s 51ms/step - loss: 3.6380e-04 - val_loss: 0.0117
# Epoch 3/150
# 45/45 [==============================] - 2s 50ms/step - loss: 3.5961e-04 - val_loss: 0.0079
# Epoch 4/150
# 45/45 [==============================] - 3s 78ms/step - loss: 3.7310e-04 - val_loss: 0.0127
# Epoch 5/150
# 45/45 [==============================] - 2s 50ms/step - loss: 4.1500e-04 - val_loss: 0.0097
# Epoch 6/150
# 45/45 [==============================] - 2s 51ms/step - loss: 3.3210e-04 - val_loss: 0.0097
# Epoch 7/150
# 45/45 [==============================] - 2s 49ms/step - loss: 3.5810e-04 - val_loss: 0.0119
# Epoch 8/150
# 45/45 [==============================] - 2s 55ms/step - loss: 3.5848e-04 - val_loss: 0.0087
# Epoch 9/150
# 45/45 [==============================] - 4s 79ms/step - loss: 3.2635e-04 - val_loss: 0.0108
# Epoch 10/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.6651e-04 - val_loss: 0.0084
# Epoch 11/150
# 45/45 [==============================] - 2s 52ms/step - loss: 3.0467e-04 - val_loss: 0.0074
# Epoch 12/150
# 45/45 [==============================] - 2s 50ms/step - loss: 3.1144e-04 - val_loss: 0.0087
# Epoch 13/150
# 45/45 [==============================] - 2s 51ms/step - loss: 3.1333e-04 - val_loss: 0.0093
# Epoch 14/150
# 45/45 [==============================] - 3s 72ms/step - loss: 2.9463e-04 - val_loss: 0.0095
# Epoch 15/150
# 45/45 [==============================] - 2s 54ms/step - loss: 2.9625e-04 - val_loss: 0.0108
# Epoch 16/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.8645e-04 - val_loss: 0.0084
# Epoch 17/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.9286e-04 - val_loss: 0.0088
# Epoch 18/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.8800e-04 - val_loss: 0.0075
# Epoch 19/150
# 45/45 [==============================] - 3s 68ms/step - loss: 2.8772e-04 - val_loss: 0.0125
# Epoch 20/150
# 45/45 [==============================] - 3s 59ms/step - loss: 2.9310e-04 - val_loss: 0.0090
# Epoch 21/150
# 45/45 [==============================] - 2s 51ms/step - loss: 3.1187e-04 - val_loss: 0.0090
# Epoch 22/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.8282e-04 - val_loss: 0.0089
# Epoch 23/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.9798e-04 - val_loss: 0.0094
# Epoch 24/150
# 45/45 [==============================] - 3s 64ms/step - loss: 2.7264e-04 - val_loss: 0.0105
# Epoch 25/150
# 45/45 [==============================] - 3s 65ms/step - loss: 3.3344e-04 - val_loss: 0.0074
# Epoch 26/150
# 45/45 [==============================] - 2s 50ms/step - loss: 3.0075e-04 - val_loss: 0.0116
# Epoch 27/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.4829e-04 - val_loss: 0.0107
# Epoch 28/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.7368e-04 - val_loss: 0.0117
# Epoch 29/150
# 45/45 [==============================] - 2s 55ms/step - loss: 3.3021e-04 - val_loss: 0.0092
# Epoch 30/150
# 45/45 [==============================] - 3s 70ms/step - loss: 2.7831e-04 - val_loss: 0.0099
# Epoch 31/150
# 45/45 [==============================] - 2s 50ms/step - loss: 3.0863e-04 - val_loss: 0.0080
# Epoch 32/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.7677e-04 - val_loss: 0.0093
# Epoch 33/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.6240e-04 - val_loss: 0.0093
# Epoch 34/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.6377e-04 - val_loss: 0.0103
# Epoch 35/150
# 45/45 [==============================] - 3s 78ms/step - loss: 2.5992e-04 - val_loss: 0.0108
# Epoch 36/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.6140e-04 - val_loss: 0.0083
# Epoch 37/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.6516e-04 - val_loss: 0.0077
# Epoch 38/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.5514e-04 - val_loss: 0.0100
# Epoch 39/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.4224e-04 - val_loss: 0.0090
# Epoch 40/150
# 45/45 [==============================] - 3s 76ms/step - loss: 2.6766e-04 - val_loss: 0.0115
# Epoch 41/150
# 45/45 [==============================] - 3s 58ms/step - loss: 2.7165e-04 - val_loss: 0.0102
# Epoch 42/150
# 45/45 [==============================] - 3s 70ms/step - loss: 2.6228e-04 - val_loss: 0.0120
# Epoch 43/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.7423e-04 - val_loss: 0.0065
# Epoch 44/150
# 45/45 [==============================] - 3s 56ms/step - loss: 2.5401e-04 - val_loss: 0.0095
# Epoch 45/150
# 45/45 [==============================] - 3s 71ms/step - loss: 2.5461e-04 - val_loss: 0.0085
# Epoch 46/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.7424e-04 - val_loss: 0.0134
# Epoch 47/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.8417e-04 - val_loss: 0.0078
# Epoch 48/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.3705e-04 - val_loss: 0.0087
# Epoch 49/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.3267e-04 - val_loss: 0.0078
# Epoch 50/150
# 45/45 [==============================] - 3s 77ms/step - loss: 2.5099e-04 - val_loss: 0.0089
# Epoch 51/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.7280e-04 - val_loss: 0.0088
# Epoch 52/150
# 45/45 [==============================] - 2s 49ms/step - loss: 2.4090e-04 - val_loss: 0.0102
# Epoch 53/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.4978e-04 - val_loss: 0.0148
# Epoch 54/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.7915e-04 - val_loss: 0.0112
# Epoch 55/150
# 45/45 [==============================] - 4s 81ms/step - loss: 2.6177e-04 - val_loss: 0.0098
# Epoch 56/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.2383e-04 - val_loss: 0.0089
# Epoch 57/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.8565e-04 - val_loss: 0.0114
# Epoch 58/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.4661e-04 - val_loss: 0.0098
# Epoch 59/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.4922e-04 - val_loss: 0.0074
# Epoch 60/150
# 45/45 [==============================] - 3s 77ms/step - loss: 3.0365e-04 - val_loss: 0.0124
# Epoch 61/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.5682e-04 - val_loss: 0.0102
# Epoch 62/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.3152e-04 - val_loss: 0.0081
# Epoch 63/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.7428e-04 - val_loss: 0.0094
# Epoch 64/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.6025e-04 - val_loss: 0.0091
# Epoch 65/150
# 45/45 [==============================] - 3s 74ms/step - loss: 2.4497e-04 - val_loss: 0.0078
# Epoch 66/150
# 45/45 [==============================] - 3s 57ms/step - loss: 2.2645e-04 - val_loss: 0.0070
# Epoch 67/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.5636e-04 - val_loss: 0.0080
# Epoch 68/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.7152e-04 - val_loss: 0.0108
# Epoch 69/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.7610e-04 - val_loss: 0.0077
# Epoch 70/150
# 45/45 [==============================] - 3s 69ms/step - loss: 2.5574e-04 - val_loss: 0.0092
# Epoch 71/150
# 45/45 [==============================] - 3s 62ms/step - loss: 2.3005e-04 - val_loss: 0.0086
# Epoch 72/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.2421e-04 - val_loss: 0.0098
# Epoch 73/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.5813e-04 - val_loss: 0.0092
# Epoch 74/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.7817e-04 - val_loss: 0.0092
# Epoch 75/150
# 45/45 [==============================] - 3s 69ms/step - loss: 2.6052e-04 - val_loss: 0.0097
# Epoch 76/150
# 45/45 [==============================] - 3s 60ms/step - loss: 2.4368e-04 - val_loss: 0.0088
# Epoch 77/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.7865e-04 - val_loss: 0.0116
# Epoch 78/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.6940e-04 - val_loss: 0.0077
# Epoch 79/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.5483e-04 - val_loss: 0.0075
# Epoch 80/150
# 45/45 [==============================] - 3s 65ms/step - loss: 2.4605e-04 - val_loss: 0.0101
# Epoch 81/150
# 45/45 [==============================] - 3s 63ms/step - loss: 2.5580e-04 - val_loss: 0.0086
# Epoch 82/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.6983e-04 - val_loss: 0.0094
# Epoch 83/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.4476e-04 - val_loss: 0.0080
# Epoch 84/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.2795e-04 - val_loss: 0.0074
# Epoch 85/150
# 45/45 [==============================] - 3s 61ms/step - loss: 2.5065e-04 - val_loss: 0.0118
# Epoch 86/150
# 45/45 [==============================] - 3s 67ms/step - loss: 2.2174e-04 - val_loss: 0.0114
# Epoch 87/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.3250e-04 - val_loss: 0.0100
# Epoch 88/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.3057e-04 - val_loss: 0.0137
# Epoch 89/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.1578e-04 - val_loss: 0.0106
# Epoch 90/150
# 45/45 [==============================] - 3s 60ms/step - loss: 2.4250e-04 - val_loss: 0.0099
# Epoch 91/150
# 45/45 [==============================] - 3s 69ms/step - loss: 2.3026e-04 - val_loss: 0.0110
# Epoch 92/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.4819e-04 - val_loss: 0.0080
# Epoch 93/150
# 45/45 [==============================] - 2s 50ms/step - loss: 2.4940e-04 - val_loss: 0.0107
# Epoch 94/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.9176e-04 - val_loss: 0.0144
# Epoch 95/150
# 45/45 [==============================] - 3s 57ms/step - loss: 2.6808e-04 - val_loss: 0.0117
# Epoch 96/150
# 45/45 [==============================] - 3s 74ms/step - loss: 2.3611e-04 - val_loss: 0.0105
# Epoch 97/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.3263e-04 - val_loss: 0.0125
# Epoch 98/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.3961e-04 - val_loss: 0.0100
# Epoch 99/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.4755e-04 - val_loss: 0.0091
# Epoch 100/150
# 45/45 [==============================] - 2s 55ms/step - loss: 2.7446e-04 - val_loss: 0.0102
# Epoch 101/150
# 45/45 [==============================] - 3s 74ms/step - loss: 2.5053e-04 - val_loss: 0.0108
# Epoch 102/150
# 45/45 [==============================] - 3s 77ms/step - loss: 2.3482e-04 - val_loss: 0.0082
# Epoch 103/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.3464e-04 - val_loss: 0.0099
# Epoch 104/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.5716e-04 - val_loss: 0.0076
# Epoch 105/150
# 45/45 [==============================] - 3s 74ms/step - loss: 2.4273e-04 - val_loss: 0.0081
# Epoch 106/150
# 45/45 [==============================] - 2s 55ms/step - loss: 2.2163e-04 - val_loss: 0.0099
# Epoch 107/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.2329e-04 - val_loss: 0.0114
# Epoch 108/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.3843e-04 - val_loss: 0.0104
# Epoch 109/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.2394e-04 - val_loss: 0.0119
# Epoch 110/150
# 45/45 [==============================] - 3s 73ms/step - loss: 2.5083e-04 - val_loss: 0.0113
# Epoch 111/150
# 45/45 [==============================] - 3s 56ms/step - loss: 2.2075e-04 - val_loss: 0.0123
# Epoch 112/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.1731e-04 - val_loss: 0.0124
# Epoch 113/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.3007e-04 - val_loss: 0.0129
# Epoch 114/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.4145e-04 - val_loss: 0.0125
# Epoch 115/150
# 45/45 [==============================] - 3s 70ms/step - loss: 2.5615e-04 - val_loss: 0.0078
# Epoch 116/150
# 45/45 [==============================] - 3s 60ms/step - loss: 2.4128e-04 - val_loss: 0.0113
# Epoch 117/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.4361e-04 - val_loss: 0.0087
# Epoch 118/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.1582e-04 - val_loss: 0.0134
# Epoch 119/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.3846e-04 - val_loss: 0.0202
# Epoch 120/150
# 45/45 [==============================] - 3s 71ms/step - loss: 2.8333e-04 - val_loss: 0.0068
# Epoch 121/150
# 45/45 [==============================] - 3s 59ms/step - loss: 2.6912e-04 - val_loss: 0.0101
# Epoch 122/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.3771e-04 - val_loss: 0.0081
# Epoch 123/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.0987e-04 - val_loss: 0.0128
# Epoch 124/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.4492e-04 - val_loss: 0.0088
# Epoch 125/150
# 45/45 [==============================] - 3s 69ms/step - loss: 2.1743e-04 - val_loss: 0.0101
# Epoch 126/150
# 45/45 [==============================] - 3s 60ms/step - loss: 2.1430e-04 - val_loss: 0.0091
# Epoch 127/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.3042e-04 - val_loss: 0.0093
# Epoch 128/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.3935e-04 - val_loss: 0.0070
# Epoch 129/150
# 45/45 [==============================] - 2s 51ms/step - loss: 2.3445e-04 - val_loss: 0.0090
# Epoch 130/150
# 45/45 [==============================] - 3s 69ms/step - loss: 2.1254e-04 - val_loss: 0.0079
# Epoch 131/150
# 45/45 [==============================] - 3s 64ms/step - loss: 2.4913e-04 - val_loss: 0.0123
# Epoch 132/150
# 45/45 [==============================] - 2s 54ms/step - loss: 2.5846e-04 - val_loss: 0.0105
# Epoch 133/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.3524e-04 - val_loss: 0.0106
# Epoch 134/150
# 45/45 [==============================] - 2s 52ms/step - loss: 2.4209e-04 - val_loss: 0.0112
# Epoch 135/150
# 45/45 [==============================] - 3s 74ms/step - loss: 2.4128e-04 - val_loss: 0.0094
# Epoch 136/150
# 45/45 [==============================] - 3s 61ms/step - loss: 2.3855e-04 - val_loss: 0.0102
# Epoch 137/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.2350e-04 - val_loss: 0.0091
# Epoch 138/150
# 45/45 [==============================] - 2s 55ms/step - loss: 2.3283e-04 - val_loss: 0.0106
# Epoch 139/150
# 45/45 [==============================] - 2s 54ms/step - loss: 2.0663e-04 - val_loss: 0.0118
# Epoch 140/150
# 45/45 [==============================] - 3s 73ms/step - loss: 2.2225e-04 - val_loss: 0.0133
# Epoch 141/150
# 45/45 [==============================] - 3s 56ms/step - loss: 2.6168e-04 - val_loss: 0.0087
# Epoch 142/150
# 45/45 [==============================] - 2s 55ms/step - loss: 2.6333e-04 - val_loss: 0.0102
# Epoch 143/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.1849e-04 - val_loss: 0.0095
# Epoch 144/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.2731e-04 - val_loss: 0.0116
# Epoch 145/150
# 45/45 [==============================] - 3s 75ms/step - loss: 2.3018e-04 - val_loss: 0.0127
# Epoch 146/150
# 45/45 [==============================] - 3s 58ms/step - loss: 2.3985e-04 - val_loss: 0.0111
# Epoch 147/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.1104e-04 - val_loss: 0.0108
# Epoch 148/150
# 45/45 [==============================] - 2s 53ms/step - loss: 2.4499e-04 - val_loss: 0.0091
# Epoch 149/150
# 45/45 [==============================] - 2s 54ms/step - loss: 2.2602e-04 - val_loss: 0.0116
# Epoch 150/150
# 45/45 [==============================] - 3s 74ms/step - loss: 2.2233e-04 - val_loss: 0.0120
# Fitting to BIDU
# Epoch 1/150
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0010 - val_loss: 0.0030
# Epoch 2/150
# 45/45 [==============================] - 2s 56ms/step - loss: 8.8099e-04 - val_loss: 0.0022
# Epoch 3/150
# 45/45 [==============================] - 2s 52ms/step - loss: 8.0960e-04 - val_loss: 0.0013
# Epoch 4/150
# 45/45 [==============================] - 2s 50ms/step - loss: 7.7234e-04 - val_loss: 9.7611e-04
# Epoch 5/150
# 45/45 [==============================] - 2s 53ms/step - loss: 7.1616e-04 - val_loss: 0.0012
# Epoch 6/150
# ...
# Epoch 3/150
# 45/45 [==============================] - 3s 63ms/step - loss: 7.8534e-04 - val_loss: 0.0011
# Epoch 4/150
# 45/45 [==============================] - 3s 61ms/step - loss: 7.5555e-04 - val_loss: 0.0012
# Epoch 5/150
# 45/45 [==============================] - 3s 61ms/step - loss: 7.4040e-04 - val_loss: 9.8170e-04
# Epoch 6/150
# 45/45 [==============================] - 4s 87ms/step - loss: 7.3541e-04 - val_loss: 9.4920e-04
# Epoch 7/150
# 45/45 [==============================] - 3s 62ms/step - loss: 7.0113e-04 - val_loss: 0.0011
# Epoch 8/150
# 45/45 [==============================] - 3s 60ms/step - loss: 6.8289e-04 - val_loss: 9.7495e-04
# Epoch 9/150
# 45/45 [==============================] - 3s 64ms/step - loss: 6.7249e-04 - val_loss: 0.0012
# Epoch 10/150
# 45/45 [==============================] - 3s 74ms/step - loss: 6.2073e-04 - val_loss: 0.0016
# Epoch 11/150
# 45/45 [==============================] - 3s 75ms/step - loss: 6.9257e-04 - val_loss: 0.0011
# Epoch 12/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.2340e-04 - val_loss: 0.0011
# Epoch 13/150
# 45/45 [==============================] - 3s 61ms/step - loss: 7.0048e-04 - val_loss: 0.0011
# Epoch 14/150
# 45/45 [==============================] - 3s 61ms/step - loss: 6.6081e-04 - val_loss: 9.6107e-04
# Epoch 15/150
# 45/45 [==============================] - 4s 81ms/step - loss: 6.9590e-04 - val_loss: 0.0010
# Epoch 16/150
# 45/45 [==============================] - 3s 68ms/step - loss: 6.1851e-04 - val_loss: 0.0011
# Epoch 17/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.2045e-04 - val_loss: 0.0010
# Epoch 18/150
# 45/45 [==============================] - 3s 61ms/step - loss: 6.2073e-04 - val_loss: 9.7366e-04
# Epoch 19/150
# 45/45 [==============================] - 3s 69ms/step - loss: 6.3347e-04 - val_loss: 0.0010
# Epoch 20/150
# 45/45 [==============================] - 4s 79ms/step - loss: 6.0657e-04 - val_loss: 9.1651e-04
# Epoch 21/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.2830e-04 - val_loss: 0.0013
# Epoch 22/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.4148e-04 - val_loss: 9.2817e-04
# Epoch 23/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.9980e-04 - val_loss: 0.0010
# Epoch 24/150
# 45/45 [==============================] - 3s 76ms/step - loss: 5.5663e-04 - val_loss: 9.7100e-04
# Epoch 25/150
# 45/45 [==============================] - 3s 72ms/step - loss: 6.6069e-04 - val_loss: 9.6992e-04
# Epoch 26/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.4422e-04 - val_loss: 0.0011
# Epoch 27/150
# 45/45 [==============================] - 3s 61ms/step - loss: 6.3935e-04 - val_loss: 9.4885e-04
# Epoch 28/150
# 45/45 [==============================] - 3s 61ms/step - loss: 6.6142e-04 - val_loss: 9.3596e-04
# Epoch 29/150
# 45/45 [==============================] - 4s 83ms/step - loss: 5.4790e-04 - val_loss: 9.2506e-04
# Epoch 30/150
# 45/45 [==============================] - 3s 76ms/step - loss: 5.8131e-04 - val_loss: 9.5123e-04
# Epoch 31/150
# 45/45 [==============================] - 4s 79ms/step - loss: 5.8805e-04 - val_loss: 9.9071e-04
# Epoch 32/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.0262e-04 - val_loss: 0.0010
# Epoch 33/150
# 45/45 [==============================] - 3s 75ms/step - loss: 5.8118e-04 - val_loss: 9.3093e-04
# Epoch 34/150
# 45/45 [==============================] - 3s 71ms/step - loss: 5.6241e-04 - val_loss: 9.1660e-04
# Epoch 35/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.4339e-04 - val_loss: 0.0010
# Epoch 36/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.9059e-04 - val_loss: 9.8644e-04
# Epoch 37/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.8233e-04 - val_loss: 0.0010
# Epoch 38/150
# 45/45 [==============================] - 4s 81ms/step - loss: 5.8994e-04 - val_loss: 0.0010
# Epoch 39/150
# 45/45 [==============================] - 3s 67ms/step - loss: 6.1852e-04 - val_loss: 0.0010
# Epoch 40/150
# 45/45 [==============================] - 3s 61ms/step - loss: 6.1328e-04 - val_loss: 0.0010
# Epoch 41/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.1612e-04 - val_loss: 9.3263e-04
# Epoch 42/150
# 45/45 [==============================] - 3s 67ms/step - loss: 5.9222e-04 - val_loss: 0.0012
# Epoch 43/150
# 45/45 [==============================] - 4s 81ms/step - loss: 5.8386e-04 - val_loss: 0.0010
# Epoch 44/150
# 45/45 [==============================] - 3s 60ms/step - loss: 5.9825e-04 - val_loss: 8.9625e-04
# Epoch 45/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.9134e-04 - val_loss: 0.0011
# Epoch 46/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.2483e-04 - val_loss: 9.7083e-04
# Epoch 47/150
# 45/45 [==============================] - 3s 75ms/step - loss: 6.1766e-04 - val_loss: 0.0013
# Epoch 48/150
# 45/45 [==============================] - 3s 74ms/step - loss: 6.2199e-04 - val_loss: 9.2628e-04
# Epoch 49/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.0638e-04 - val_loss: 9.2164e-04
# Epoch 50/150
# 45/45 [==============================] - 3s 63ms/step - loss: 6.3112e-04 - val_loss: 9.2886e-04
# Epoch 51/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.3671e-04 - val_loss: 0.0014
# Epoch 52/150
# 45/45 [==============================] - 4s 86ms/step - loss: 6.1697e-04 - val_loss: 9.2006e-04
# Epoch 53/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.1169e-04 - val_loss: 0.0017
# Epoch 54/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.6223e-04 - val_loss: 0.0010
# Epoch 55/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.7810e-04 - val_loss: 9.4056e-04
# Epoch 56/150
# 45/45 [==============================] - 3s 69ms/step - loss: 5.6979e-04 - val_loss: 9.5096e-04
# Epoch 57/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.6042e-04 - val_loss: 0.0015
# Epoch 58/150
# 45/45 [==============================] - 3s 65ms/step - loss: 7.1928e-04 - val_loss: 9.4651e-04
# Epoch 59/150
# 45/45 [==============================] - 3s 61ms/step - loss: 6.0123e-04 - val_loss: 0.0012
# Epoch 60/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.0235e-04 - val_loss: 8.9708e-04
# Epoch 61/150
# 45/45 [==============================] - 4s 81ms/step - loss: 5.5743e-04 - val_loss: 8.9789e-04
# Epoch 62/150
# 45/45 [==============================] - 3s 67ms/step - loss: 5.8076e-04 - val_loss: 9.0406e-04
# Epoch 63/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.6639e-04 - val_loss: 9.0669e-04
# Epoch 64/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.0741e-04 - val_loss: 9.0974e-04
# Epoch 65/150
# 45/45 [==============================] - 3s 65ms/step - loss: 6.3959e-04 - val_loss: 0.0014
# Epoch 66/150
# 45/45 [==============================] - 4s 84ms/step - loss: 6.2661e-04 - val_loss: 0.0012
# Epoch 67/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.3010e-04 - val_loss: 9.3467e-04
# Epoch 68/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.1527e-04 - val_loss: 9.2552e-04
# Epoch 69/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.6776e-04 - val_loss: 0.0012
# Epoch 70/150
# 45/45 [==============================] - 3s 75ms/step - loss: 5.7217e-04 - val_loss: 9.0622e-04
# Epoch 71/150
# 45/45 [==============================] - 3s 76ms/step - loss: 6.4161e-04 - val_loss: 9.1107e-04
# Epoch 72/150
# 45/45 [==============================] - 3s 61ms/step - loss: 5.6888e-04 - val_loss: 8.9058e-04
# Epoch 73/150
# 45/45 [==============================] - 3s 61ms/step - loss: 5.5158e-04 - val_loss: 9.3264e-04
# Epoch 74/150
# 45/45 [==============================] - 3s 66ms/step - loss: 5.9041e-04 - val_loss: 0.0011
# Epoch 75/150
# 45/45 [==============================] - 4s 83ms/step - loss: 6.0221e-04 - val_loss: 9.7024e-04
# Epoch 76/150
# 45/45 [==============================] - 3s 64ms/step - loss: 5.8082e-04 - val_loss: 8.8488e-04
# Epoch 77/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.6958e-04 - val_loss: 8.5830e-04
# Epoch 78/150
# 45/45 [==============================] - 3s 64ms/step - loss: 6.1743e-04 - val_loss: 0.0011
# Epoch 79/150
# 45/45 [==============================] - 3s 71ms/step - loss: 6.0346e-04 - val_loss: 8.9076e-04
# Epoch 80/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.4128e-04 - val_loss: 8.6753e-04
# Epoch 81/150
# 45/45 [==============================] - 3s 63ms/step - loss: 6.0819e-04 - val_loss: 0.0011
# Epoch 82/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.3311e-04 - val_loss: 0.0010
# Epoch 83/150
# 45/45 [==============================] - 3s 61ms/step - loss: 5.7293e-04 - val_loss: 8.6299e-04
# Epoch 84/150
# 45/45 [==============================] - 4s 80ms/step - loss: 6.2253e-04 - val_loss: 0.0011
# Epoch 85/150
# 45/45 [==============================] - 3s 69ms/step - loss: 5.7758e-04 - val_loss: 9.8500e-04
# Epoch 86/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.9512e-04 - val_loss: 9.2619e-04
# Epoch 87/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.9748e-04 - val_loss: 8.6914e-04
# Epoch 88/150
# 45/45 [==============================] - 3s 67ms/step - loss: 5.6560e-04 - val_loss: 8.5400e-04
# Epoch 89/150
# 45/45 [==============================] - 4s 83ms/step - loss: 5.9848e-04 - val_loss: 0.0010
# Epoch 90/150
# 45/45 [==============================] - 3s 63ms/step - loss: 6.6218e-04 - val_loss: 0.0014
# Epoch 91/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.4967e-04 - val_loss: 9.0194e-04
# Epoch 92/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.8587e-04 - val_loss: 9.0903e-04
# Epoch 93/150
# 45/45 [==============================] - 3s 74ms/step - loss: 5.8295e-04 - val_loss: 8.5291e-04
# Epoch 94/150
# 45/45 [==============================] - 3s 73ms/step - loss: 5.6719e-04 - val_loss: 8.7539e-04
# Epoch 95/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.8475e-04 - val_loss: 8.5216e-04
# Epoch 96/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.9945e-04 - val_loss: 8.6883e-04
# Epoch 97/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.1863e-04 - val_loss: 9.0951e-04
# Epoch 98/150
# 45/45 [==============================] - 4s 83ms/step - loss: 5.4365e-04 - val_loss: 8.9033e-04
# Epoch 99/150
# 45/45 [==============================] - 3s 65ms/step - loss: 5.9978e-04 - val_loss: 0.0015
# Epoch 100/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.9668e-04 - val_loss: 8.5170e-04
# Epoch 101/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.6570e-04 - val_loss: 9.2536e-04
# Epoch 102/150
# 45/45 [==============================] - 4s 88ms/step - loss: 5.8411e-04 - val_loss: 9.1821e-04
# Epoch 103/150
# 45/45 [==============================] - 4s 93ms/step - loss: 6.1839e-04 - val_loss: 9.5364e-04
# Epoch 104/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.7871e-04 - val_loss: 8.8797e-04
# Epoch 105/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.3570e-04 - val_loss: 8.9505e-04
# Epoch 106/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.5659e-04 - val_loss: 9.1364e-04
# Epoch 107/150
# 45/45 [==============================] - 3s 72ms/step - loss: 5.8574e-04 - val_loss: 0.0012
# Epoch 108/150
# 45/45 [==============================] - 3s 76ms/step - loss: 5.9004e-04 - val_loss: 8.7582e-04
# Epoch 109/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.9805e-04 - val_loss: 0.0011
# Epoch 110/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.7990e-04 - val_loss: 9.0288e-04
# Epoch 111/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.4791e-04 - val_loss: 9.8893e-04
# Epoch 112/150
# 45/45 [==============================] - 4s 82ms/step - loss: 6.3117e-04 - val_loss: 8.8426e-04
# Epoch 113/150
# 45/45 [==============================] - 3s 67ms/step - loss: 6.1455e-04 - val_loss: 9.5825e-04
# Epoch 114/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.2528e-04 - val_loss: 0.0011
# Epoch 115/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.9386e-04 - val_loss: 8.8864e-04
# Epoch 116/150
# 45/45 [==============================] - 3s 69ms/step - loss: 6.0018e-04 - val_loss: 9.0243e-04
# Epoch 117/150
# 45/45 [==============================] - 4s 80ms/step - loss: 5.7979e-04 - val_loss: 8.6871e-04
# Epoch 118/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.8993e-04 - val_loss: 9.7434e-04
# Epoch 119/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.9037e-04 - val_loss: 8.9240e-04
# Epoch 120/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.9328e-04 - val_loss: 0.0010
# Epoch 121/150
# 45/45 [==============================] - 3s 77ms/step - loss: 6.1299e-04 - val_loss: 0.0014
# Epoch 122/150
# 45/45 [==============================] - 3s 72ms/step - loss: 5.9976e-04 - val_loss: 0.0012
# Epoch 123/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.8283e-04 - val_loss: 9.8518e-04
# Epoch 124/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.3865e-04 - val_loss: 9.4473e-04
# Epoch 125/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.9035e-04 - val_loss: 8.8797e-04
# Epoch 126/150
# 45/45 [==============================] - 4s 80ms/step - loss: 6.6773e-04 - val_loss: 8.9967e-04
# Epoch 127/150
# 45/45 [==============================] - 3s 65ms/step - loss: 5.8003e-04 - val_loss: 8.9275e-04
# Epoch 128/150
# 45/45 [==============================] - 3s 64ms/step - loss: 5.7978e-04 - val_loss: 8.8581e-04
# Epoch 129/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.1677e-04 - val_loss: 0.0010
# Epoch 130/150
# 45/45 [==============================] - 3s 71ms/step - loss: 5.7135e-04 - val_loss: 9.4177e-04
# Epoch 131/150
# 45/45 [==============================] - 4s 79ms/step - loss: 6.1506e-04 - val_loss: 0.0012
# Epoch 132/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.7193e-04 - val_loss: 8.8165e-04
# Epoch 133/150
# 45/45 [==============================] - 3s 62ms/step - loss: 5.6665e-04 - val_loss: 9.0641e-04
# Epoch 134/150
# 45/45 [==============================] - 3s 62ms/step - loss: 6.2177e-04 - val_loss: 8.7354e-04
# Epoch 135/150
# 45/45 [==============================] - 4s 80ms/step - loss: 5.7490e-04 - val_loss: 0.0010
# Epoch 136/150
# 45/45 [==============================] - 3s 70ms/step - loss: 5.8546e-04 - val_loss: 8.4459e-04
# Epoch 137/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.5513e-04 - val_loss: 0.0012
# Epoch 138/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.8748e-04 - val_loss: 8.5759e-04
# Epoch 139/150
# 45/45 [==============================] - 3s 71ms/step - loss: 5.5107e-04 - val_loss: 8.7634e-04
# Epoch 140/150
# 45/45 [==============================] - 4s 80ms/step - loss: 5.5951e-04 - val_loss: 0.0010
# Epoch 141/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.6624e-04 - val_loss: 8.9610e-04
# Epoch 142/150
# 45/45 [==============================] - 3s 65ms/step - loss: 5.8404e-04 - val_loss: 8.4921e-04
# Epoch 143/150
# 45/45 [==============================] - 3s 63ms/step - loss: 6.2942e-04 - val_loss: 9.3602e-04
# Epoch 144/150
# 45/45 [==============================] - 4s 79ms/step - loss: 6.3185e-04 - val_loss: 8.9683e-04
# Epoch 145/150
# 45/45 [==============================] - 3s 70ms/step - loss: 6.3292e-04 - val_loss: 9.0450e-04
# Epoch 146/150
# 45/45 [==============================] - 3s 63ms/step - loss: 5.8195e-04 - val_loss: 0.0014
# Epoch 147/150
# 45/45 [==============================] - 3s 63ms/step - loss: 6.1621e-04 - val_loss: 9.6042e-04
# Epoch 148/150
# 45/45 [==============================] - 3s 67ms/step - loss: 5.8994e-04 - val_loss: 9.1495e-04
# Epoch 149/150
# 45/45 [==============================] - 4s 82ms/step - loss: 6.4681e-04 - val_loss: 9.0113e-04
# Epoch 150/150
# 45/45 [==============================] - 3s 63ms/step - loss: 6.1592e-04 - val_loss: 8.8235e-04

# %%
for i in stockList:
  plt.rcParams['figure.figsize'] = (10,8)
  plt.plot(history.history['loss']) # tb
  plt.plot(history.history['val_loss'])
  plt.title('model loss of ' + i)
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()

# %%
pred_result = {}
for i in stockList:
    y_true = scaler[i].inverse_transform(testset[i]["y"].reshape(-1,1))
    y_pred = scaler[i].inverse_transform(model.predict(testset[i]["X"]))
    pred_result[i] = {}
    pred_result[i]["True"] = y_true
    pred_result[i]["Pred"] = y_pred
    plt.figure(figsize=(8,8))
    plt.title("{}".format(i))
    plt.plot(y_true, color = 'b')
    plt.plot(y_pred, color = 'r')
    plt.xlabel("Time value (day)")
    plt.ylabel("Close value (point)")
    plt.legend(('prediction', 'actual'),loc='upper left', fontsize=12)
# Out:
# 14/14 [==============================] - 1s 14ms/step
# 14/14 [==============================] - 0s 12ms/step
# 14/14 [==============================] - 0s 12ms/step
# 14/14 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 12ms/step
# 14/14 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 12ms/step
# 14/14 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 15ms/step

# %%
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
for i in stockList:
    true = testset[i]["y"].reshape(-1,1)
    pred = model.predict(testset[i]["X"])
    errors = mean_squared_error(true,pred)
    errors2 = mean_squared_error(true, pred, squared=False)
    errors3 = mean_absolute_error(true, pred)
    errors4 = mean_absolute_error(true, pred)*100
# report error
    print('Test errors of ' + i + ":")
    print('mean squared error : %.8f MSE' % (errors))
    print('root mean squared error : %.8f RMSE' % (errors2))
    print('mean absolute error: %.8f MAE' %(errors3))
    print('mean absolute percentage error: %.8f MAPE' %(errors4) + "\n")
# Out:
# 14/14 [==============================] - 0s 13ms/step
# Test errors of AMZN:
# mean squared error : 0.00096477 MSE
# root mean squared error : 0.03106082 RMSE
# mean absolute error: 0.02285062 MAE
# mean absolute percentage error: 2.28506200 MAPE
#
# 14/14 [==============================] - 0s 13ms/step
# Test errors of NVDA:
# mean squared error : 0.00059860 MSE
# root mean squared error : 0.02446635 RMSE
# mean absolute error: 0.01861720 MAE
# mean absolute percentage error: 1.86172028 MAPE
#
# 14/14 [==============================] - 0s 13ms/step
# Test errors of AAPL:
# mean squared error : 0.00058738 MSE
# root mean squared error : 0.02423598 RMSE
# mean absolute error: 0.01745041 MAE
# mean absolute percentage error: 1.74504139 MAPE
#
# 14/14 [==============================] - 0s 13ms/step
# Test errors of BIDU:
# mean squared error : 0.00112430 MSE
# root mean squared error : 0.03353057 RMSE
# mean absolute error: 0.02307138 MAE
# mean absolute percentage error: 2.30713825 MAPE
#
# 14/14 [==============================] - 0s 13ms/step
# Test errors of GOOG:
# mean squared error : 0.00126810 MSE
# root mean squared error : 0.03561035 RMSE
# mean absolute error: 0.02503106 MAE
# mean absolute percentage error: 2.50310562 MAPE
#
# 14/14 [==============================] - 0s 21ms/step
# Test errors of INTC:
# mean squared error : 0.00373726 MSE
# root mean squared error : 0.06113310 RMSE
# mean absolute error: 0.03814838 MAE
# mean absolute percentage error: 3.81483810 MAPE
#
# 14/14 [==============================] - 0s 20ms/step
# Test errors of MSFT:
# mean squared error : 0.00105081 MSE
# root mean squared error : 0.03241627 RMSE
# mean absolute error: 0.02230774 MAE
# mean absolute percentage error: 2.23077434 MAPE
#
# 14/14 [==============================] - 0s 19ms/step
# Test errors of NFLX:
# mean squared error : 0.00128446 MSE
# root mean squared error : 0.03583930 RMSE
# mean absolute error: 0.02595907 MAE
# mean absolute percentage error: 2.59590731 MAPE
#
# 14/14 [==============================] - 0s 20ms/step
# Test errors of TCEHY:
# mean squared error : 0.00105299 MSE
# root mean squared error : 0.03244977 RMSE
# mean absolute error: 0.02417637 MAE
# mean absolute percentage error: 2.41763666 MAPE
#
# 14/14 [==============================] - 0s 21ms/step
# Test errors of TSLA:
# mean squared error : 0.00046360 MSE
# root mean squared error : 0.02153127 RMSE
# mean absolute error: 0.01635219 MAE
# mean absolute percentage error: 1.63521933 MAPE

# %%
df_new1 = {}
for i in stockList:
    df_new1[i] = {}
    df_new1[i]["Test"]  = df_[i].query('Date >= "2019-03-27"').reset_index(drop = False)

# %%
for i in stockList:
  y_pred = scaler[i].inverse_transform(model.predict(testset[i]["X"]))
  df_new1[i]["Test"].drop(columns=['Open', 'High','Low','Adj Close','Volume'],inplace = True)
  df_new1[i]["Test"].insert(2,"Predicted", y_pred)
# Out:
# 14/14 [==============================] - 0s 20ms/step
# 14/14 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 12ms/step
# 14/14 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 14ms/step
# 14/14 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 12ms/step
# 14/14 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 13ms/step
# 14/14 [==============================] - 0s 14ms/step

# %%
df_new1[i]["Test"]
# Out:
#            Date       Close   Predicted
# 0    2019-03-27   18.322001   20.103868
# 1    2019-03-28   18.574667   20.293846
# 2    2019-03-29   18.657333   20.455355
# 3    2019-04-01   19.278667   20.553106
# 4    2019-04-02   19.058666   20.886490
# ..          ...         ...         ...
# 438  2020-12-18  231.666672  215.502228
# 439  2020-12-21  216.619995  225.201401
# 440  2020-12-22  213.446671  220.188080
# 441  2020-12-23  215.326660  214.373016
# 442  2020-12-24  220.589996  214.593292
#
# [443 rows x 3 columns]

# %%
for i in stockList:
  # y_true = scaler[i].inverse_transform(testset[i]["y"].reshape(-1,1))
  # y_pred = scaler[i].inverse_transform(model.predict(testset[i]["X"]))
  df_pred = pd.DataFrame(data = df_new1[i]["Test"])
  df_pred.to_csv(i + "_output.csv")
